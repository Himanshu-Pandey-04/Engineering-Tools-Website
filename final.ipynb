# %%
from inspect import signature, getmembers, isfunction
import importlib.util as iu
import sys, os, re

# %%
path = r'C:\Users\hp\AppData\Local\Programs\Python\Python39\Lib\site-packages\codes'

pyDT_To_HTML = {
    float: 'number',
    int: 'number',
    str: 'text',
    range: 'range',
    list: 'range',
    tuple: 'range',
    set: 'range',
}

ignoreEntities = {
    'files' : [
        '.*__init__.*',
        '.*manager.*',
        '.*\.ipynb',
        '.*\.pyc'
    ],
    
    'dirs' : [
        '.*__pycache__.*',
    ],
}

# %%
def get_funcs(file : str, path : str):
    spec = iu.spec_from_file_location(file, path)
    foo = iu.module_from_spec(spec)
    spec.loader.exec_module(foo)
    return getmembers(foo, isfunction)

# %%
funcLib = {}
HTMLcode = ''''''
encloser = ''' <section class="sidebar col-3">
</section>'''

outer = '''<div class="dropdowns">
    <button class="btn Subjects" id="btn-{{key}}" onclick="DropDownToggle('{{key}}')">{{ key }}</button>
    #children#
</div>'''

innerMost = '''<ul class="menu" id="list-{{key}}">
    #leaf#
</ul>'''

leaf = '''<li class="item"><a href="#">{{link}}</a></li>'''

# %%
def hierar_n_lib(parent):
    """Hierarchy and Function Library Generator
        =======================================
        1. Generates Folder -> Sub-folder -> File -> Function Hierarchy
        2. Generates Dictionary containing Function name mapped to function description and call
        
        Parameters
        ----------
        1. parent - Path to directory containing files and folders of neccessary functions

        Returns
        -------
        1. hierar : dict -> Directory Hierarchy from root folder to function names
        2. funcLib : dict -> Function-name mapped to function description and call

        Example
        -------
        >>> hierarchy = hierar_n_lib(path_to_folder)
        """
    if os.path.isfile(parent): return None
    hierar = {}

    for item in os.listdir(parent):
        ignore = False
        for igDir in ignoreEntities['dirs']:
            if re.search(igDir, item):
                ignore = True
                break
        if ignore: continue

        fullPath = parent + '\\' + item
        if os.path.isfile(fullPath):
            for file in ignoreEntities['files']:
                if re.search(file, item): break
            else:
                hierar[item] = []
                for name_func in get_funcs(item, fullPath):
                    if name_func[0][:3] == 'Igr': continue
                    hierar[item].append(name_func[0])
                    func = name_func[1]
                    Sig = signature(func)
                    funcLib[func.__name__] = {}
                    funcLib[func.__name__]['docS'] = func.__doc__
                    funcLib[func.__name__]['params'] = { name : Type.annotation for name, Type in Sig.parameters.items() }
                    funcLib[func.__name__]['returns'] = { 'r1' : Sig.return_annotation }
                    funcLib[func.__name__]['call'] = func
        else: hierar[item] = hierar_n_lib(fullPath)
    return hierar

# %%
hierarchy = hierar_n_lib(path)

# %% [markdown]
# # Testing

# %% [markdown]
# ### Directory Hierarchy Check

# %%
hierarchy
# Out:
# {'BCN': {'bcn.py': ['CRC_Decoder',
#    'CRC_Encoder',
#    'Hamming_Distance',
#    'MHD_ED_EC',
#    '_1sComp_CheckSum_Checker',
#    '_1sComp_CheckSum_Generator']},
#  'Decorators.py': ['MathDecor'],
#  'DS': {'Strings': {'Add_Ons.py': ['Split', 'Split_Older', 'makePairs'],
#    'Data_Cleaner.py': ['Clean', 'Clean_Resume']},
#   'Trie': {'Trie.py': ['Reach', 'Split', 's']}},
#  'LDCO': {'ldco.py': ['BCD_To_Decimal',
#    'BCD_To_Ex3',
#    'Binary_Adder',
#    'Binary_Division',
#    'Binary_Subtractor',
#    'Binary_Subtractor_2',
#    'Binary_To_Gray',
#    'COMPLIMENTS',
#    'Decimal_To_BCD',
#    'Decimal_To_X',
#    'NS_Code_Converter',
#    'Print_List',
#    'Propositional_Truth_Table',
#    'X_To_Decimal',
#    '_1sCOMPLIMENT',
#    '_2sCOMPLIMENT']},
#  'MATH': {'combinatorics': {'Permutations_and_Combinations.py': ['Combinations',
#     'Permutations']},
#   'Expansions.py': [],
#   'fusion.py': ['Chinese_Remainder_Theorem',
#    'Co_Prime',
#    'Congruent_Modulo',
#    'Determinant',
#    'Euler_Totient_Function',
#    'Fibonacci',
#    'Inverse_Euler_Totient_Function',
#    'Josephus_Problem',
#    'Last_Digit_Determiner',
#    'ModAll',
#    'Prime_Check',
#    'Prime_Factors',
#    'Sieve',
#    'Signum'],
#   'more.py': ['addNums'],
#   'Randomizer.py': ['BiasedEvents',
#    'Random_Dates',
#    'Random_Element',
#    'Random_Range',
#    'Shuffle_Zip',
#    'Shuffler'],
#   'seq_n_series.py': ['APs_smallest_common_ele'],
#   'sets.py': []},
#  'TOOLS': {'Calculator.py': ['Calculator', 'Split'],
#   'Templates.py': ['Calculator', 'Function_Menu', 'MathDecor', 'Split']}}

# %%
def print_indent(items, indent = 0, indent_increment = 8):
    if items is None: return
    for item in items:
        print(' '*indent + item)
        if isinstance(items, dict) and isinstance(items[item], dict):
            print_indent(items[item], indent+indent_increment, indent_increment)
    
print_indent(hierarchy)
# Out:
# BCN
#         bcn.py
# Decorators.py
# DS
#         Strings
#                 Add_Ons.py
#                 Data_Cleaner.py
#         Trie
#                 Trie.py
# LDCO
#         ldco.py
# MATH
#         combinatorics
#                 Permutations_and_Combinations.py
#         Expansions.py
#         fusion.py
#         more.py
#         Randomizer.py
#         seq_n_series.py
#         sets.py
# TOOLS
#         Calculator.py
#         Templates.py

# %% [markdown]
# ### Function Library Testing

# %%
funcLib
# Out:
# {'CRC_Decoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': <function bcn.py.CRC_Decoder(Data: str, Divisor: str) -> str>},
#  'CRC_Encoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': <function bcn.py.CRC_Encoder(Data: str, Divisor: str) -> str>},
#  'Hamming_Distance': {'docS': None,
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': int},
#   'call': <function bcn.py.Hamming_Distance(word_1: list, word_2: list = None) -> int>},
#  'MHD_ED_EC': {'docS': 'Minimum hamming distance(MHD), Error detection(ED), Error correction(EC)\n        ==========================================================\n        Calculates\n        ----------\n        1. Minimum Hamming Distance (d_min) between given 2 code-words\n        2. Number of errors that can be detected\n        3. Number of errors that can be corrected\n    ',
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': dict[str, int]},
#   'call': <function bcn.py.MHD_ED_EC(word_1: list, word_2: list = None) -> dict>},
#  '_1sComp_CheckSum_Checker': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': <function bcn.py._1sComp_CheckSum_Checker(Data_List: list) -> list>},
#  '_1sComp_CheckSum_Generator': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': <function bcn.py._1sComp_CheckSum_Generator(Data_List: list) -> list>},
#  'MathDecor': {'docS': 'APPLY A METHOD ON A SET/LIST/TUPLE OF ENTRIES',
#   'params': {'Function': inspect._empty,
#    'args': inspect._empty,
#    'kwargs': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Templates.py.MathDecor(Function, *args, **kwargs)>},
#  'Split': {'docS': 'Split\n       =====\n\n       splits given text/string by given splitters of any length\n\n       Parameters\n       ----------\n\n       1. text : str :: The string on which splitting action has to be performed\n       2. splitters : list[str] :: List of splitters (splitters can be of length > 1)\n       3. keepSplitters : bool :: If True, splitters are also included in the resulting list of elements\n       4. stripElements : bool :: If True, elements included in the result list are first stripped\n\n       Returns\n       -------\n       List of resulting strings after split action\n    ',
#   'params': {'text': str,
#    'splitters': list[str],
#    'keepSplitters': bool,
#    'stripElements': bool},
#   'returns': {'r1': list[str]},
#   'call': <function MyLibs.GrandCollection.DS.Strings.Add_Ons.Split(text: str, splitters: list, keepSplitters: bool = False, stripElements: bool = False) -> list>},
#  'Split_Older': {'docS': 'Can split text given by splitters of lenght 1',
#   'params': {'String': str,
#    'Splitters': inspect._empty,
#    'KeepSplitters': inspect._empty,
#    'StripElements': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Add_Ons.py.Split_Older(String: str, Splitters, KeepSplitters=False, StripElements=False)>},
#  'makePairs': {'docS': "\n    Pair Maker\n    =========\n        Finds and creates corresponding pairs of all types of brackets given in the 'bracket_list' present in the 'code'.\n\n        Parameters\n        ----------\n        1. Code : str - given string of code\n        2. Bracket List : list - all types of brackets whose pair has to be searched and mapped\n\n        Returns\n        -------\n        A dictionary that maps an opening bracket position to corresponding closing bracket position\n\n        Example\n        -------\n        >>> bracePairs = makePairs(code)\n\n        >>> for open, close in bracePairs.items():\n\n        >>>    print(code[open : close+1])\n    ",
#   'params': {'code': str, 'bracket_list': inspect._empty},
#   'returns': {'r1': dict},
#   'call': <function Add_Ons.py.makePairs(code: str, bracket_list=['[', '{', '(', '<']) -> dict>},
#  'Clean': {'docS': None,
#   'params': {'sentence': str},
#   'returns': {'r1': inspect._empty},
#   'call': <function Data_Cleaner.py.Clean(sentence: str)>},
#  'Clean_Resume': {'docS': None,
#   'params': {'resumeText': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Data_Cleaner.py.Clean_Resume(resumeText)>},
#  'Reach': {'docS': None,
#   'params': {'Dict': inspect._empty, 'Key_List': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Trie.py.Reach(Dict, Key_List)>},
#  's': {'docS': None,
#   'params': {'t': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Trie.py.s(t=1)>},
#  'BCD_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.BCD_To_Decimal(nfc: str, EachDigitLen: int = 4) -> str>},
#  'BCD_To_Ex3': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.BCD_To_Ex3(nfc: str, EachDigitLen: int = 4) -> str>},
#  'Binary_Adder': {'docS': 'PERFORMS ADDITION ON A LIST OF NUMBERS IN BASE SYSTEM Base_System',
#   'params': {'Numbers_List': list, 'Base_System': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Adder(Numbers_List: list, Base_System: int = 10) -> str>},
#  'Binary_Division': {'docS': None,
#   'params': {'Dividend': str, 'Divisor': str},
#   'returns': {'r1': tuple},
#   'call': <function ldco.py.Binary_Division(Dividend: str, Divisor: str) -> tuple>},
#  'Binary_Subtractor': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str, 'Borrow': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Subtractor(Minuend: str, Subtrahend: str, Borrow: int = 0) -> str>},
#  'Binary_Subtractor_2': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Subtractor_2(Minuend: str, Subtrahend: str) -> str>},
#  'Binary_To_Gray': {'docS': None,
#   'params': {'Number': str, 'BTG': bool},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_To_Gray(Number: str, BTG: bool = True) -> str>},
#  'COMPLIMENTS': {'docS': None,
#   'params': {},
#   'returns': {'r1': None},
#   'call': <function ldco.py.COMPLIMENTS() -> None>},
#  'Decimal_To_BCD': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Decimal_To_BCD(nfc: str, EachDigitLen: int = 4) -> str>},
#  'Decimal_To_X': {'docS': None,
#   'params': {'nDec': int, 'to': int, 'conv': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Decimal_To_X(nDec: int, to: int, conv: str = '') -> str>},
#  'NS_Code_Converter': {'docS': None,
#   'params': {'nfc': str, 'From': str, 'To': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.NS_Code_Converter(nfc: str = None, From: str = None, To: str = None) -> str>},
#  'Print_List': {'docS': None,
#   'params': {'Message': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function ldco.py.Print_List(Message='Choice')>},
#  'Propositional_Truth_Table': {'docS': None,
#   'params': {'Exp': str},
#   'returns': {'r1': None},
#   'call': <function ldco.py.Propositional_Truth_Table(Exp: str = '((pvqvy)^~q)>r=t=s') -> None>},
#  'X_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'From': int, 'nDec': int},
#   'returns': {'r1': int},
#   'call': <function ldco.py.X_To_Decimal(nfc: str, From: int, nDec: int = 0) -> int>},
#  '_1sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py._1sCOMPLIMENT(Number: str) -> str>},
#  '_2sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py._2sCOMPLIMENT(Number: str) -> str>},
#  'Combinations': {'docS': 'COMBINATIONS :- Returns List of All Possible Combinations of Input Data',
#   'params': {'Elements': list, 'Positions': int},
#   'returns': {'r1': inspect._empty},
#   'call': <function Permutations_and_Combinations.py.Combinations(Elements: list, Positions: int = -1)>},
#  'Permutations': {'docS': 'PERMUTATIONS :- Returns List of All Possible Permutations of Input Data',
#   'params': {'Elements': list, 'Positions': int, 'Allow_Repetitions': bool},
#   'returns': {'r1': inspect._empty},
#   'call': <function Permutations_and_Combinations.py.Permutations(Elements: list, Positions: int = -1, Allow_Repetitions: bool = False)>},
#  'Chinese_Remainder_Theorem': {'docS': 'CHINESE REMAINDER THEOREM :- Implements CRT on Given Divisor and Remainder Arrays',
#   'params': {'Divisor_Array': list, 'Remainder_Array': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Chinese_Remainder_Theorem(Divisor_Array: list, Remainder_Array: list) -> int>},
#  'Co_Prime': {'docS': 'CO-PRIME :- Checks Whether Given Pair of Numbers are Co-Prime',
#   'params': {'Number_1': int, 'Number_2': int},
#   'returns': {'r1': bool},
#   'call': <function fusion.py.Co_Prime(Number_1: int, Number_2: int) -> bool>},
#  'Congruent_Modulo': {'docS': "CONGRUENT_MODULO :- Groups 'List' elements giving identical modulus value w.r.t. 'Number'",
#   'params': {'List': list, 'N': int},
#   'returns': {'r1': dict},
#   'call': <function fusion.py.Congruent_Modulo(List: list, N: int) -> dict>},
#  'Determinant': {'docS': 'JUST ONE LINE DETERMINANT CALCULATOR :- Calculates Determinant of given Matrix',
#   'params': {'Mat': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Determinant(Mat: list) -> int>},
#  'Euler_Totient_Function': {'docS': 'EULER TOTIENT FUNCTION :- Computes ETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Euler_Totient_Function(Number: int) -> int>},
#  'Fibonacci': {'docS': 'FIBONACCI :- Provides fibonacci result upto 998\n    n -> depicts element position in the fibonacci sequence\n    ',
#   'params': {'n': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Fibonacci(n: int) -> int>},
#  'Inverse_Euler_Totient_Function': {'docS': 'INVERSE EULER TOTIENT FUNCTION :- Computes IETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Inverse_Euler_Totient_Function(Number: int) -> int>},
#  'Josephus_Problem': {'docS': 'JOSEPHUS PROBLEM :- Theoretical problem related to a certain counting-out game',
#   'params': {'Step': int, 'Sequence': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Josephus_Problem(Step: int, Sequence: list) -> int>},
#  'Last_Digit_Determiner': {'docS': 'PRINTS LAST DIGIT OF EXPONENTIAL RESULT :- Determines Last Digit of Result (Base ^ Exp)',
#   'params': {'Base': int, 'Exponent': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Last_Digit_Determiner(Base: int, Exponent: int) -> int>},
#  'ModAll': {'docS': "MODALL :- Performs modulus(%) operation on given elements in 'List' w.r.t. 'Number'",
#   'params': {'List': list, 'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.ModAll(List: list, Number: int) -> list>},
#  'Prime_Check': {'docS': 'PRIME CHECK :- Checks if a Number is Prime / Composite / Neither Prime nor Composite',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Prime_Check(Number: int) -> int>},
#  'Prime_Factors': {'docS': 'PRIME FACTORS :- Computes List of Prime Factors',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.Prime_Factors(Number: int) -> list>},
#  'Sieve': {'docS': 'SIEVE OF ERASTOSTHENES :- Computes Sieve of Eratosthenes',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.Sieve(Number: int) -> list>},
#  'Signum': {'docS': 'SIGNUM :- Checks Sign of Number in Range = { -1, 0, 1 }',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Signum(Number: int) -> int>},
#  'addNums': {'docS': '\n    Numbers Adder\n    =============\n    Given a list of list of digits of numbers, the function returns the list of digits of the resulting sum.\n    The lists(numbers) can be of different sizes\n    \n    Parameters\n    ----------\n    1. lst1 : list - digits of first number\n    2. lst2 : list - digits of second number\n    3. *args : (Optional) list of lists - more numbers\n\n    Returns\n    -------\n    the list of digits of the resulting Sum (carry considered)\n\n    Example\n    -------\n    >>> num1 = [7, 6, 9, 8, 8]              # Depicts number 76988\n    >>> num2 = [5, 9, 2]                    # Depicts number 592\n    >>> num3 = [3, 5, 1, 7, 4]              # Depicts number 35174\n    >>> print(addNums(num1, num2, num3))    # Output: [1, 1, 2, 7, 5, 4] (112754)\n    ',
#   'params': {'lst1': list[int], 'lst2': list[int], 'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function more.py.addNums(lst1: list, lst2: list, *args)>},
#  'BiasedEvents': {'docS': 'Biased Events\n        ============\n        Method Takes Input of Biased Probability of unique elements and number of outcomes/draws\n    ',
#   'params': {'Sequence': list, 'NoOfDraws': int},
#   'returns': {'r1': int},
#   'call': <function Randomizer.py.BiasedEvents(Sequence: list, NoOfDraws: int) -> int>},
#  'Random_Dates': {'docS': 'Random Dates Generator\n        =====================\n        Generates random dates according to input parameters\n\n        Parameters\n        ----------\n        dayR : int -> day range\n        monthR : int -> month range\n        yearR : int -> year range\n        Format : int -> date format\n    ',
#   'params': {'Freq': int,
#    'dayR': tuple,
#    'monthR': tuple,
#    'yearR': tuple,
#    'Format': str},
#   'returns': {'r1': inspect._empty},
#   'call': <function Randomizer.py.Random_Dates(Freq: int = 10, dayR: tuple = (1, 31), monthR: tuple = (1, 12), yearR: tuple = (2000, 2021), Format: str = 'YYYY-MM-DD')>},
#  'Random_Element': {'docS': None,
#   'params': {'Sequence': list[int], 'start': int, 'end': int},
#   'returns': {'r1': list[int]},
#   'call': <function Randomizer.py.Random_Element(Sequence: list, start: int = 0, end: int = -1) -> list>},
#  'Random_Range': {'docS': 'Random Range\n        ===========\n        Returns random number in specified range\n    ',
#   'params': {'start': int, 'end': int},
#   'returns': {'r1': int},
#   'call': <function Randomizer.py.Random_Range(start: int, end: int) -> int>},
#  'Shuffle_Zip': {'docS': 'Shuffle Zip\n        ==========\n        Shuffle Individual Sequences and Group(zip)\n    ',
#   'params': {'length': int,
#    'Sequence1': list[str],
#    'Sequence2': list[str],
#    'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Randomizer.py.Shuffle_Zip(length: int = -1, Sequence1: list = ['Coco', 'Nova'], Sequence2: list = ['Nina', 'Hande', 'Candice'], *args)>},
#  'Shuffler': {'docS': 'Shuffler\n        =======\n        For Picking Random element from a sequence\n    ',
#   'params': {'Sequence': typing.Union[list, tuple, set]},
#   'returns': {'r1': typing.Union[list, tuple, set, int]},
#   'call': <function Randomizer.py.Shuffler(Sequence: Union[list, tuple, set]) -> Union[list, tuple, set, int]>},
#  'APs_smallest_common_ele': {'docS': '\n        Smallest Common Element\n        =======================\n        Finds smallest common element of the Arithmetic Progressions (APs) whose initial terms and common differences are given\n        AP 1: a + (n-1)*b\n        AP 2: b + (m-1)*d\n        \n        Parameters\n        ----------\n        a : int -> initial term of first AP\n        b : int -> common difference of first AP\n        c : int -> initial term of second AP\n        d : int -> common difference of second AP\n\n        Returns\n        -------\n        int : first common term (first intersection) of 2 APs which satisfies (a+(n-1)*b = c+(m-1)*d) if exists, else -1\n    ',
#   'params': {'a': int, 'b': int, 'c': int, 'd': int},
#   'returns': {'r1': int},
#   'call': <function seq_n_series.py.APs_smallest_common_ele(a: int, b: int, c: int, d: int) -> int>},
#  'Calculator': {'docS': None,
#   'params': {'Exp': inspect._empty, 'OperPrec': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function MyLibs.GrandCollection.Tools.Calculator.Calculator(Exp, OperPrec={'&': 1, '|': 1, '>': 2, '<': 2, '~': 6, '!': 7, '√': 5, '-': 3, '+': 3, '×': 4, '*': 4, '%': 4, '/': 4, '÷': 4, '^': 5, 'log': 6, 'sin': 8, 'cos': 8, 'tan': 8, 'cot': 8, 'cosec': 8, 'sec': 8, 'asin': 8, 'acos': 8, 'atan': 8})>},
#  'Function_Menu': {'docS': None,
#   'params': {'Func_Library': list},
#   'returns': {'r1': inspect._empty},
#   'call': <function Templates.py.Function_Menu(Func_Library: list)>}}

# %%
print(funcLib['Co_Prime']['call'](23,45))
funcLib['Co_Prime']['call'](23,46)
# Out:
# True
# False

# %%
"""
<div className='lvl_1'>
    <div className='lvl_2'>
    </div>
</div>
"""

# %%
import final
hierar, funcLib = final.hierar_n_lib()

# %%
hierar
# Out:
# {'BCN': {'bcn.py': ['CRC_Decoder',
#    'CRC_Encoder',
#    'Hamming_Distance',
#    'MHD_ED_EC',
#    '_1sComp_CheckSum_Checker',
#    '_1sComp_CheckSum_Generator']},
#  'Decorators.py': ['MathDecor'],
#  'DS': {'Strings': {'Add_Ons.py': ['Split', 'Split_Older', 'makePairs'],
#    'Data_Cleaner.py': ['Clean', 'Clean_Resume']},
#   'Trie': {'Trie.py': ['Reach', 'Split', 's']}},
#  'LDCO': {'ldco.py': ['BCD_To_Decimal',
#    'BCD_To_Ex3',
#    'Binary_Adder',
#    'Binary_Division',
#    'Binary_Subtractor',
#    'Binary_Subtractor_2',
#    'Binary_To_Gray',
#    'COMPLIMENTS',
#    'Decimal_To_BCD',
#    'Decimal_To_X',
#    'NS_Code_Converter',
#    'Print_List',
#    'Propositional_Truth_Table',
#    'X_To_Decimal',
#    '_1sCOMPLIMENT',
#    '_2sCOMPLIMENT']},
#  'MATH': {'combinatorics': {'Permutations_and_Combinations.py': ['Combinations',
#     'Permutations']},
#   'Expansions.py': [],
#   'fusion.py': ['Chinese_Remainder_Theorem',
#    'Co_Prime',
#    'Congruent_Modulo',
#    'Determinant',
#    'Euler_Totient_Function',
#    'Fibonacci',
#    'Inverse_Euler_Totient_Function',
#    'Josephus_Problem',
#    'Last_Digit_Determiner',
#    'ModAll',
#    'Prime_Check',
#    'Prime_Factors',
#    'Sieve',
#    'Signum'],
#   'more.py': ['addNums'],
#   'Randomizer.py': ['BiasedEvents',
#    'Random_Dates',
#    'Random_Element',
#    'Random_Range',
#    'Shuffle_Zip',
#    'Shuffler'],
#   'seq_n_series.py': ['APs_smallest_common_ele'],
#   'sets.py': []},
#  'TOOLS': {'Calculator.py': ['Calculator', 'Split'],
#   'Templates.py': ['Calculator', 'Function_Menu', 'MathDecor', 'Split']}}

# %%
funcLib
# Out:
# {'CRC_Decoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': <function bcn.py.CRC_Decoder(Data: str, Divisor: str) -> str>},
#  'CRC_Encoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': <function bcn.py.CRC_Encoder(Data: str, Divisor: str) -> str>},
#  'Hamming_Distance': {'docS': None,
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': int},
#   'call': <function bcn.py.Hamming_Distance(word_1: list, word_2: list = None) -> int>},
#  'MHD_ED_EC': {'docS': 'Minimum hamming distance(MHD), Error detection(ED), Error correction(EC)\n        ==========================================================\n        Calculates\n        ----------\n        1. Minimum Hamming Distance (d_min) between given 2 code-words\n        2. Number of errors that can be detected\n        3. Number of errors that can be corrected\n    ',
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': dict[str, int]},
#   'call': <function bcn.py.MHD_ED_EC(word_1: list, word_2: list = None) -> dict>},
#  '_1sComp_CheckSum_Checker': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': <function bcn.py._1sComp_CheckSum_Checker(Data_List: list) -> list>},
#  '_1sComp_CheckSum_Generator': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': <function bcn.py._1sComp_CheckSum_Generator(Data_List: list) -> list>},
#  'MathDecor': {'docS': 'APPLY A METHOD ON A SET/LIST/TUPLE OF ENTRIES',
#   'params': {'Function': inspect._empty,
#    'args': inspect._empty,
#    'kwargs': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Templates.py.MathDecor(Function, *args, **kwargs)>},
#  'Split': {'docS': 'Split\n       =====\n\n       splits given text/string by given splitters of any length\n\n       Parameters\n       ----------\n\n       1. text : str :: The string on which splitting action has to be performed\n       2. splitters : list[str] :: List of splitters (splitters can be of length > 1)\n       3. keepSplitters : bool :: If True, splitters are also included in the resulting list of elements\n       4. stripElements : bool :: If True, elements included in the result list are first stripped\n\n       Returns\n       -------\n       List of resulting strings after split action\n    ',
#   'params': {'text': str,
#    'splitters': list[str],
#    'keepSplitters': bool,
#    'stripElements': bool},
#   'returns': {'r1': list[str]},
#   'call': <function MyLibs.GrandCollection.DS.Strings.Add_Ons.Split(text: str, splitters: list, keepSplitters: bool = False, stripElements: bool = False) -> list>},
#  'Split_Older': {'docS': 'Can split text given by splitters of lenght 1',
#   'params': {'String': str,
#    'Splitters': inspect._empty,
#    'KeepSplitters': inspect._empty,
#    'StripElements': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Add_Ons.py.Split_Older(String: str, Splitters, KeepSplitters=False, StripElements=False)>},
#  'makePairs': {'docS': "\n    Pair Maker\n    =========\n        Finds and creates corresponding pairs of all types of brackets given in the 'bracket_list' present in the 'code'.\n\n        Parameters\n        ----------\n        1. Code : str - given string of code\n        2. Bracket List : list - all types of brackets whose pair has to be searched and mapped\n\n        Returns\n        -------\n        A dictionary that maps an opening bracket position to corresponding closing bracket position\n\n        Example\n        -------\n        >>> bracePairs = makePairs(code)\n\n        >>> for open, close in bracePairs.items():\n\n        >>>    print(code[open : close+1])\n    ",
#   'params': {'code': str, 'bracket_list': inspect._empty},
#   'returns': {'r1': dict},
#   'call': <function Add_Ons.py.makePairs(code: str, bracket_list=['[', '{', '(', '<']) -> dict>},
#  'Clean': {'docS': None,
#   'params': {'sentence': str},
#   'returns': {'r1': inspect._empty},
#   'call': <function Data_Cleaner.py.Clean(sentence: str)>},
#  'Clean_Resume': {'docS': None,
#   'params': {'resumeText': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Data_Cleaner.py.Clean_Resume(resumeText)>},
#  'Reach': {'docS': None,
#   'params': {'Dict': inspect._empty, 'Key_List': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Trie.py.Reach(Dict, Key_List)>},
#  's': {'docS': None,
#   'params': {'t': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Trie.py.s(t=1)>},
#  'BCD_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.BCD_To_Decimal(nfc: str, EachDigitLen: int = 4) -> str>},
#  'BCD_To_Ex3': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.BCD_To_Ex3(nfc: str, EachDigitLen: int = 4) -> str>},
#  'Binary_Adder': {'docS': 'PERFORMS ADDITION ON A LIST OF NUMBERS IN BASE SYSTEM Base_System',
#   'params': {'Numbers_List': list, 'Base_System': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Adder(Numbers_List: list, Base_System: int = 10) -> str>},
#  'Binary_Division': {'docS': None,
#   'params': {'Dividend': str, 'Divisor': str},
#   'returns': {'r1': tuple},
#   'call': <function ldco.py.Binary_Division(Dividend: str, Divisor: str) -> tuple>},
#  'Binary_Subtractor': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str, 'Borrow': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Subtractor(Minuend: str, Subtrahend: str, Borrow: int = 0) -> str>},
#  'Binary_Subtractor_2': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Subtractor_2(Minuend: str, Subtrahend: str) -> str>},
#  'Binary_To_Gray': {'docS': None,
#   'params': {'Number': str, 'BTG': bool},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_To_Gray(Number: str, BTG: bool = True) -> str>},
#  'COMPLIMENTS': {'docS': None,
#   'params': {},
#   'returns': {'r1': None},
#   'call': <function ldco.py.COMPLIMENTS() -> None>},
#  'Decimal_To_BCD': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Decimal_To_BCD(nfc: str, EachDigitLen: int = 4) -> str>},
#  'Decimal_To_X': {'docS': None,
#   'params': {'nDec': int, 'to': int, 'conv': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Decimal_To_X(nDec: int, to: int, conv: str = '') -> str>},
#  'NS_Code_Converter': {'docS': None,
#   'params': {'nfc': str, 'From': str, 'To': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.NS_Code_Converter(nfc: str = None, From: str = None, To: str = None) -> str>},
#  'Print_List': {'docS': None,
#   'params': {'Message': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function ldco.py.Print_List(Message='Choice')>},
#  'Propositional_Truth_Table': {'docS': None,
#   'params': {'Exp': str},
#   'returns': {'r1': None},
#   'call': <function ldco.py.Propositional_Truth_Table(Exp: str = '((pvqvy)^~q)>r=t=s') -> None>},
#  'X_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'From': int, 'nDec': int},
#   'returns': {'r1': int},
#   'call': <function ldco.py.X_To_Decimal(nfc: str, From: int, nDec: int = 0) -> int>},
#  '_1sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py._1sCOMPLIMENT(Number: str) -> str>},
#  '_2sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py._2sCOMPLIMENT(Number: str) -> str>},
#  'Combinations': {'docS': 'COMBINATIONS :- Returns List of All Possible Combinations of Input Data',
#   'params': {'Elements': list, 'Positions': int},
#   'returns': {'r1': inspect._empty},
#   'call': <function Permutations_and_Combinations.py.Combinations(Elements: list, Positions: int = -1)>},
#  'Permutations': {'docS': 'PERMUTATIONS :- Returns List of All Possible Permutations of Input Data',
#   'params': {'Elements': list, 'Positions': int, 'Allow_Repetitions': bool},
#   'returns': {'r1': inspect._empty},
#   'call': <function Permutations_and_Combinations.py.Permutations(Elements: list, Positions: int = -1, Allow_Repetitions: bool = False)>},
#  'Chinese_Remainder_Theorem': {'docS': 'CHINESE REMAINDER THEOREM :- Implements CRT on Given Divisor and Remainder Arrays',
#   'params': {'Divisor_Array': list, 'Remainder_Array': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Chinese_Remainder_Theorem(Divisor_Array: list, Remainder_Array: list) -> int>},
#  'Co_Prime': {'docS': 'CO-PRIME :- Checks Whether Given Pair of Numbers are Co-Prime',
#   'params': {'Number_1': int, 'Number_2': int},
#   'returns': {'r1': bool},
#   'call': <function fusion.py.Co_Prime(Number_1: int, Number_2: int) -> bool>},
#  'Congruent_Modulo': {'docS': "CONGRUENT_MODULO :- Groups 'List' elements giving identical modulus value w.r.t. 'Number'",
#   'params': {'List': list, 'N': int},
#   'returns': {'r1': dict},
#   'call': <function fusion.py.Congruent_Modulo(List: list, N: int) -> dict>},
#  'Determinant': {'docS': 'JUST ONE LINE DETERMINANT CALCULATOR :- Calculates Determinant of given Matrix',
#   'params': {'Mat': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Determinant(Mat: list) -> int>},
#  'Euler_Totient_Function': {'docS': 'EULER TOTIENT FUNCTION :- Computes ETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Euler_Totient_Function(Number: int) -> int>},
#  'Fibonacci': {'docS': 'FIBONACCI :- Provides fibonacci result upto 998\n    n -> depicts element position in the fibonacci sequence\n    ',
#   'params': {'n': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Fibonacci(n: int) -> int>},
#  'Inverse_Euler_Totient_Function': {'docS': 'INVERSE EULER TOTIENT FUNCTION :- Computes IETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Inverse_Euler_Totient_Function(Number: int) -> int>},
#  'Josephus_Problem': {'docS': 'JOSEPHUS PROBLEM :- Theoretical problem related to a certain counting-out game',
#   'params': {'Step': int, 'Sequence': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Josephus_Problem(Step: int, Sequence: list) -> int>},
#  'Last_Digit_Determiner': {'docS': 'PRINTS LAST DIGIT OF EXPONENTIAL RESULT :- Determines Last Digit of Result (Base ^ Exp)',
#   'params': {'Base': int, 'Exponent': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Last_Digit_Determiner(Base: int, Exponent: int) -> int>},
#  'ModAll': {'docS': "MODALL :- Performs modulus(%) operation on given elements in 'List' w.r.t. 'Number'",
#   'params': {'List': list, 'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.ModAll(List: list, Number: int) -> list>},
#  'Prime_Check': {'docS': 'PRIME CHECK :- Checks if a Number is Prime / Composite / Neither Prime nor Composite',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Prime_Check(Number: int) -> int>},
#  'Prime_Factors': {'docS': 'PRIME FACTORS :- Computes List of Prime Factors',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.Prime_Factors(Number: int) -> list>},
#  'Sieve': {'docS': 'SIEVE OF ERASTOSTHENES :- Computes Sieve of Eratosthenes',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.Sieve(Number: int) -> list>},
#  'Signum': {'docS': 'SIGNUM :- Checks Sign of Number in Range = { -1, 0, 1 }',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Signum(Number: int) -> int>},
#  'addNums': {'docS': '\n    Numbers Adder\n    =============\n    Given a list of list of digits of numbers, the function returns the list of digits of the resulting sum.\n    The lists(numbers) can be of different sizes\n    \n    Parameters\n    ----------\n    1. lst1 : list - digits of first number\n    2. lst2 : list - digits of second number\n    3. *args : (Optional) list of lists - more numbers\n\n    Returns\n    -------\n    the list of digits of the resulting Sum (carry considered)\n\n    Example\n    -------\n    >>> num1 = [7, 6, 9, 8, 8]              # Depicts number 76988\n    >>> num2 = [5, 9, 2]                    # Depicts number 592\n    >>> num3 = [3, 5, 1, 7, 4]              # Depicts number 35174\n    >>> print(addNums(num1, num2, num3))    # Output: [1, 1, 2, 7, 5, 4] (112754)\n    ',
#   'params': {'lst1': list[int], 'lst2': list[int], 'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function more.py.addNums(lst1: list, lst2: list, *args)>},
#  'BiasedEvents': {'docS': 'Biased Events\n        ============\n        Method Takes Input of Biased Probability of unique elements and number of outcomes/draws\n    ',
#   'params': {'Sequence': list, 'NoOfDraws': int},
#   'returns': {'r1': int},
#   'call': <function Randomizer.py.BiasedEvents(Sequence: list, NoOfDraws: int) -> int>},
#  'Random_Dates': {'docS': 'Random Dates Generator\n        =====================\n        Generates random dates according to input parameters\n\n        Parameters\n        ----------\n        dayR : int -> day range\n        monthR : int -> month range\n        yearR : int -> year range\n        Format : int -> date format\n    ',
#   'params': {'Freq': int,
#    'dayR': tuple,
#    'monthR': tuple,
#    'yearR': tuple,
#    'Format': str},
#   'returns': {'r1': inspect._empty},
#   'call': <function Randomizer.py.Random_Dates(Freq: int = 10, dayR: tuple = (1, 31), monthR: tuple = (1, 12), yearR: tuple = (2000, 2021), Format: str = 'YYYY-MM-DD')>},
#  'Random_Element': {'docS': None,
#   'params': {'Sequence': list[int], 'start': int, 'end': int},
#   'returns': {'r1': list[int]},
#   'call': <function Randomizer.py.Random_Element(Sequence: list, start: int = 0, end: int = -1) -> list>},
#  'Random_Range': {'docS': 'Random Range\n        ===========\n        Returns random number in specified range\n    ',
#   'params': {'start': int, 'end': int},
#   'returns': {'r1': int},
#   'call': <function Randomizer.py.Random_Range(start: int, end: int) -> int>},
#  'Shuffle_Zip': {'docS': 'Shuffle Zip\n        ==========\n        Shuffle Individual Sequences and Group(zip)\n    ',
#   'params': {'length': int,
#    'Sequence1': list[str],
#    'Sequence2': list[str],
#    'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Randomizer.py.Shuffle_Zip(length: int = -1, Sequence1: list = ['Coco', 'Nova'], Sequence2: list = ['Nina', 'Hande', 'Candice'], *args)>},
#  'Shuffler': {'docS': 'Shuffler\n        =======\n        For Picking Random element from a sequence\n    ',
#   'params': {'Sequence': typing.Union[list, tuple, set]},
#   'returns': {'r1': typing.Union[list, tuple, set, int]},
#   'call': <function Randomizer.py.Shuffler(Sequence: Union[list, tuple, set]) -> Union[list, tuple, set, int]>},
#  'APs_smallest_common_ele': {'docS': '\n        Smallest Common Element\n        =======================\n        Finds smallest common element of the Arithmetic Progressions (APs) whose initial terms and common differences are given\n        AP 1: a + (n-1)*b\n        AP 2: b + (m-1)*d\n        \n        Parameters\n        ----------\n        a : int -> initial term of first AP\n        b : int -> common difference of first AP\n        c : int -> initial term of second AP\n        d : int -> common difference of second AP\n\n        Returns\n        -------\n        int : first common term (first intersection) of 2 APs which satisfies (a+(n-1)*b = c+(m-1)*d) if exists, else -1\n    ',
#   'params': {'a': int, 'b': int, 'c': int, 'd': int},
#   'returns': {'r1': int},
#   'call': <function seq_n_series.py.APs_smallest_common_ele(a: int, b: int, c: int, d: int) -> int>},
#  'Calculator': {'docS': None,
#   'params': {'Exp': inspect._empty, 'OperPrec': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function MyLibs.GrandCollection.Tools.Calculator.Calculator(Exp, OperPrec={'&': 1, '|': 1, '>': 2, '<': 2, '~': 6, '!': 7, '√': 5, '-': 3, '+': 3, '×': 4, '*': 4, '%': 4, '/': 4, '÷': 4, '^': 5, 'log': 6, 'sin': 8, 'cos': 8, 'tan': 8, 'cot': 8, 'cosec': 8, 'sec': 8, 'asin': 8, 'acos': 8, 'atan': 8})>},
#  'Function_Menu': {'docS': None,
#   'params': {'Func_Library': list},
#   'returns': {'r1': inspect._empty},
#   'call': <function Templates.py.Function_Menu(Func_Library: list)>}}

# %%
HTMLcode = ''''''
encloser = ''' <section class="sidebar col-3">
</section>'''

outer = '''<div class="dropdowns"><button class="btn Subjects" id="btn-$name$" onclick="DropDownToggle('$name$')">$name$</button>$children$</div>'''

innerMost = '''<ul class="menu" id="list-$name$">$children$</ul>'''

leaf = '''<li class="item"><a href="#">$name$</a></li>'''

# %%
def get_html(parent = path):
    if os.path.isfile(parent): return None
    dirChildren = []

    for item in os.listdir(parent):
        ignore = False
        for igDir in ignoreEntities['dirs']:
            if re.search(igDir, item):
                ignore = True
                break
        if ignore: continue

        fullPath = parent + '\\' + item
        if os.path.isfile(fullPath):
            for igrFile in ignoreEntities['files']:
                if re.search(igrFile, item): break
            else:
                funcs = []
                for name_func in get_funcs(item, fullPath):
                    if name_func[0][:3] == 'Igr': continue
                    funcs.append(leaf.replace('$name$', name_func[0]))
                dirChildren.append(innerMost.replace('$children$', ''.join(funcs)).replace('$name$', os.path.splitext(item)[0]))
        else: dirChildren.append(get_html(fullPath))
    return outer.replace('$children$', ''.join(dirChildren)).replace('$name$', parent[parent.rindex('\\')+1:])

# %%
print(get_html())
# Out:
# <div class="dropdowns"><button class="btn Subjects" id="btn-codes" onclick="DropDownToggle('codes')">codes</button><div class="dropdowns"><button class="btn Subjects" id="btn-BCN" onclick="DropDownToggle('BCN')">BCN</button><ul class="menu" id="list-bcn.py"><li class="item"><a href="#">CRC_Decoder</a></li><li class="item"><a href="#">CRC_Encoder</a></li><li class="item"><a href="#">Hamming_Distance</a></li><li class="item"><a href="#">MHD_ED_EC</a></li><li class="item"><a href="#">_1sComp_CheckSum_Checker</a></li><li class="item"><a href="#">_1sComp_CheckSum_Generator</a></li></ul></div><ul class="menu" id="list-Decorators.py"><li class="item"><a href="#">MathDecor</a></li></ul><div class="dropdowns"><button class="btn Subjects" id="btn-DS" onclick="DropDownToggle('DS')">DS</button><div class="dropdowns"><button class="btn Subjects" id="btn-Strings" onclick="DropDownToggle('Strings')">Strings</button><ul class="menu" id="list-Add_Ons.py"><li class="item"><a href="#">Split</a></li><li class="item"><a href="#">Split_Older</a></li><li class="item"><a href="#">makePairs</a></li></ul><ul class="menu" id="list-Data_Cleaner.py"><li class="item"><a href="#">Clean</a></li><li class="item"><a href="#">Clean_Resume</a></li></ul></div><div class="dropdowns"><button class="btn Subjects" id="btn-Trie" onclick="DropDownToggle('Trie')">Trie</button><ul class="menu" id="list-Trie.py"><li class="item"><a href="#">Reach</a></li><li class="item"><a href="#">Split</a></li><li class="item"><a href="#">s</a></li></ul></div></div><div class="dropdowns"><button class="btn Subjects" id="btn-LDCO" onclick="DropDownToggle('LDCO')">LDCO</button><ul class="menu" id="list-ldco.py"><li class="item"><a href="#">BCD_To_Decimal</a></li><li class="item"><a href="#">BCD_To_Ex3</a></li><li class="item"><a href="#">Binary_Adder</a></li><li class="item"><a href="#">Binary_Division</a></li><li class="item"><a href="#">Binary_Subtractor</a></li><li class="item"><a href="#">Binary_Subtractor_2</a></li><li class="item"><a href="#">Binary_To_Gray</a></li><li class="item"><a href="#">COMPLIMENTS</a></li><li class="item"><a href="#">Decimal_To_BCD</a></li><li class="item"><a href="#">Decimal_To_X</a></li><li class="item"><a href="#">NS_Code_Converter</a></li><li class="item"><a href="#">Print_List</a></li><li class="item"><a href="#">Propositional_Truth_Table</a></li><li class="item"><a href="#">X_To_Decimal</a></li><li class="item"><a href="#">_1sCOMPLIMENT</a></li><li class="item"><a href="#">_2sCOMPLIMENT</a></li></ul></div><div class="dropdowns"><button class="btn Subjects" id="btn-MATH" onclick="DropDownToggle('MATH')">MATH</button><div class="dropdowns"><button class="btn Subjects" id="btn-combinatorics" onclick="DropDownToggle('combinatorics')">combinatorics</button><ul class="menu" id="list-Permutations_and_Combinations.py"><li class="item"><a href="#">Combinations</a></li><li class="item"><a href="#">Permutations</a></li></ul></div><ul class="menu" id="list-Expansions.py"></ul><ul class="menu" id="list-fusion.py"><li class="item"><a href="#">Chinese_Remainder_Theorem</a></li><li class="item"><a href="#">Co_Prime</a></li><li class="item"><a href="#">Congruent_Modulo</a></li><li class="item"><a href="#">Determinant</a></li><li class="item"><a href="#">Euler_Totient_Function</a></li><li class="item"><a href="#">Fibonacci</a></li><li class="item"><a href="#">Inverse_Euler_Totient_Function</a></li><li class="item"><a href="#">Josephus_Problem</a></li><li class="item"><a href="#">Last_Digit_Determiner</a></li><li class="item"><a href="#">ModAll</a></li><li class="item"><a href="#">Prime_Check</a></li><li class="item"><a href="#">Prime_Factors</a></li><li class="item"><a href="#">Sieve</a></li><li class="item"><a href="#">Signum</a></li></ul><ul class="menu" id="list-more.py"><li class="item"><a href="#">addNums</a></li></ul><ul class="menu" id="list-Randomizer.py"><li class="item"><a href="#">BiasedEvents</a></li><li class="item"><a href="#">Random_Dates</a></li><li cla ...

# %%
import final
import pyperclip as pc
htmlCode = final.get_html()
print(htmlCode)
pc.copy(htmlCode)
# Out:
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-codes" onclick="DropDownToggle('codes')">codes</button>
#     <ul class="menu" id="list-codes">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Competitive_Programming" onclick="DropDownToggle('Competitive_Programming')">Competitive_Programming</button>
#     <ul class="menu" id="list-Competitive_Programming">
#
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Computer_Networks" onclick="DropDownToggle('Computer_Networks')">Computer_Networks</button>
#     <ul class="menu" id="list-Computer_Networks">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-bcn" onclick="DropDownToggle('bcn')">bcn</button>
#     <ul class="menu" id="list-bcn">
#         <li class="item"><a href="#">CRC_Decoder</a></li><li class="item"><a href="#">CRC_Encoder</a></li><li class="item"><a href="#">Hamming_Distance</a></li><li class="item"><a href="#">MHD_ED_EC</a></li><li class="item"><a href="#">_1sComp_CheckSum_Checker</a></li><li class="item"><a href="#">_1sComp_CheckSum_Generator</a></li>
#     </ul>
# </div>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Data_Structures_and_Algorithms" onclick="DropDownToggle('Data_Structures_and_Algorithms')">Data_Structures_and_Algorithms</button>
#     <ul class="menu" id="list-Data_Structures_and_Algorithms">
#
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Decorators" onclick="DropDownToggle('Decorators')">Decorators</button>
#     <ul class="menu" id="list-Decorators">
#         <li class="item"><a href="#">MathDecor</a></li>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-DS" onclick="DropDownToggle('DS')">DS</button>
#     <ul class="menu" id="list-DS">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Strings" onclick="DropDownToggle('Strings')">Strings</button>
#     <ul class="menu" id="list-Strings">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Add_Ons" onclick="DropDownToggle('Add_Ons')">Add_Ons</button>
#     <ul class="menu" id="list-Add_Ons">
#         <li class="item"><a href="#">Split</a></li><li class="item"><a href="#">Split_Older</a></li><li class="item"><a href="#">makePairs</a></li>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Data_Cleaner" onclick="DropDownToggle('Data_Cleaner')">Data_Cleaner</button>
#     <ul class="menu" id="list-Data_Cleaner">
#         <li class="item"><a href="#">Clean</a></li><li class="item"><a href="#">Clean_Resume</a></li>
#     </ul>
# </div>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Trie" onclick="DropDownToggle('Trie')">Trie</button>
#     <ul class="menu" id="list-Trie">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Trie" onclick="DropDownToggle('Trie')">Trie</button>
#     <ul class="menu" id="list-Trie">
#         <li class="item"><a href="#">Reach</a></li><li class="item"><a href="#">s</a></li>
#     </ul>
# </div>
#     </ul>
# </div>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-LDCO" onclick="DropDownToggle('LDCO')">LDCO</button>
#     <ul class="menu" id="list-LDCO">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-ldco" onclick="DropDownToggle('ldco')">ldco</button>
#     <ul class="menu" id="list-ldco">
#         <li class="item"><a href="#">BCD_To_Decimal</a></li><li class="item"><a href="#">BCD_To_Ex3</a></li><li class="item"><a href="#">Binary_Adder</a></li><li class="item"><a href="#">Binary_Division</a></li><li class="item"><a href="#">Binary_Subtractor</a></li><li class="item"><a href="#">Binary_Subtractor_2</a></li><li class="item"><a href="#">Binary_To_Gray</a></li><li class="item"><a href="#">COMPLIMENTS</a></li><li class="item"><a href="#">Decimal_To_BCD</a></li><li class="item"><a href="#">Decimal_To_X</a></li><li class="item"><a href="#">NS_Code_Converter</a></li><li class="item"><a href="#">Print_List</a></li><li class="item"><a href="#">Propositional_Truth_Table</a></li><li class="item"><a href="#">X_To_Decimal</a></li><li class="item"><a href="#">_1sCOMPLIMENT</a></li><li class="item"><a href="#">_2sCOMPLIMENT</a></li>
#     </ul>
# </div>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-MATH" onclick="DropDownToggle('MATH')">MATH</button>
#     <ul class="menu" id="list-MATH">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-combinatorics" onclick="DropDownToggle('combinatorics')">combinatorics</button>
#     <ul class="menu" id="list-combinatorics">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Permutations_and_Combinations" onclick="DropDownToggle('Permutations_and_Combinations')">Permutations_and_Combinations</button>
#     <ul class="menu" id="list-Permutations_and_Combinations">
#         <li class="item"><a href="#">Combinations</a></li><li class="item"><a href="#">Permutations</a></li>
#     </ul>
# </div>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Expansions" onclick="DropDownToggle('Expansions')">Expansions</button>
#     <ul class="menu" id="list-Expansions">
#
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-fusion" onclick="DropDownToggle('fusion')">fusion</button>
#     <ul class="menu" id="list-fusion">
#         <li class="item"><a href="#">Chinese_Remainder_Theorem</a></li><li class="item"><a href="#">Co_Prime</a></li><li class="item"><a href="#">Congruent_Modulo</a></li><li class="item"><a href="#">Determinant</a></li><li class="item"><a href="#">Euler_Totient_Function</a></li><li class="item"><a href="#">Fibonacci</a></li><li class="item"><a href="#">Inverse_Euler_Totient_Function</a></li><li class="item"><a href="#">Josephus_Problem</a></li><li class="item"><a href="#">Last_Digit_Determiner</a></li><li class="item"><a href="#">ModAll</a></li><li class="item"><a href="#">Prime_Check</a></li><li class="item"><a href="#">Prime_Factors</a></li><li class="item"><a href="#">Sieve</a></li><li class="item"><a href="#">Signum</a></li>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-more" onclick="DropDownToggle('more')">more</button>
#     <ul class="menu" id="list-more">
#         <li class="item"><a href="#">addNums</a></li>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Randomizer" onclick="DropDownToggle('Randomizer')">Randomizer</button>
#     <ul class="menu" id="list-Randomizer">
#         <li class="item"><a href="#">BiasedEvents</a></li><li class="item"><a href="#">Random_Dates</a></li><li class="item"><a href="#">Random_Element</a></li><li class="item"><a href="#">Random_Range</a></li><li class="item"><a href="#">Shuffle_Zip</a></li><li class="item"><a href="#">Shuffler</a></li>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-seq_n_series" onclick="DropDownToggle('seq_n_series')">seq_n_series</button>
#     <ul class="menu" id="list-seq_n_series">
#         <li class="item"><a href="#">APs_smallest_common_ele</a></li>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-sets" onclick="DropDownToggle('sets')">sets</button>
#     <ul class="menu" id="list-sets">
#
#     </ul>
# </div>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-OS" onclick="DropDownToggle('OS')">OS</button>
#     <ul class="menu" id="list-OS">
#
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-TOOLS" onclick="DropDownToggle('TOOLS')">TOOLS</button>
#     <ul class="menu" id="list-TOOLS">
#
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Calculator" onclick="DropDownToggle('Calculator')">Calculator</button>
#     <ul class="menu" id="list-Calculator">
#         <li class="item"><a href="#">Calculator</a></li><li class="item"><a href="#">Split</a></li>
#     </ul>
# </div>
# <div class="dropdowns">
#     <button class="btn Subjects" id="btn-Templates" onclick="DropDownToggle('Templates')">Templates</button>
#     <ul class="menu" id="list-Templates">
#         <li class="item"><a href="#">Calculator</a></li><li class="item"><a href="#">Function_Menu</a></li><li class="item"><a href="#">MathDecor</a></li><li class="item"><a href="#">Split</a></li>
#     </ul>
# </div>
#     </ul>
# </div>
#     </ul>
# </div>

# %%
str.title('Hi How are you')
# Out:
# 'Hi How Are You'

# %%
'codes'.split('\\')
# Out:
# ['codes']
