# %%
from inspect import signature, getmembers, isfunction
import importlib.util as iu
import sys, os, re
# from typing import DefaultDict

functions = {}
codeFiles = []
codes = r'.\codes'

# %%
ignoreEntities = {
    'files' : [
        '.*__init__.*',
        '.*manager.*'
    ],
    
    'dirs' : [
        '.*__pycache__.*',
    ],
}

# %%
for (root, _, files) in os.walk(codes):
    ignore = False
    for dir in ignoreEntities['dirs']:
        if re.search(dir, root):
            ignore = True
    
    if ignore: continue

    for item in files:
        for file in ignoreEntities['files']:
            if re.search(file, item): break
        else: codeFiles.append((item, os.path.join(root, item),))

# %%
for file_path in codeFiles:
    spec = iu.spec_from_file_location(*file_path)
    foo = iu.module_from_spec(spec)
    spec.loader.exec_module(foo)
    for func in getmembers(foo, isfunction):
        functions[func[0]] = func[1]
        # functions[func[0]] = functions.get(func[0], set()).union({func[1]})
# Out:
# c:\Users\niral\Envs\src\Engineering-Tools-Website\manager\codes\LDCO\ldco.py:445: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   def NEGATION(A):           return 1 if int(A) is 0 else 0
# c:\Users\niral\Envs\src\Engineering-Tools-Website\manager\codes\LDCO\ldco.py:451: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   def IMPLIES(A, B):         return 0 if(int(A) is 1 and int(B) is 0) else 1
# c:\Users\niral\Envs\src\Engineering-Tools-Website\manager\codes\LDCO\ldco.py:451: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   def IMPLIES(A, B):         return 0 if(int(A) is 1 and int(B) is 0) else 1

# %%
for name,func in functions.items():
    print(name, func)
    print('\n\n')
    # if func[0] == 'Co_Prime':
        # print(func[0], func[1](3, 14))
# Out:
# CRC_Decoder <function CRC_Decoder at 0x0000018AA9EC9430>
#
#
#
# CRC_Encoder <function CRC_Encoder at 0x0000018AA9201B80>
#
#
#
# MHD_ED_EC <function MHD_ED_EC at 0x0000018AA9EC9670>
#
#
#
# TimeIt <function TimeIt at 0x0000018AA98B2160>
#
#
#
# _1sComp_CheckSum_Checker <function _1sComp_CheckSum_Checker at 0x0000018AA9EC9550>
#
#
#
# _1sComp_CheckSum_Generator <function _1sComp_CheckSum_Generator at 0x0000018AA9EC94C0>
#
#
#
# hamming_distance <function hamming_distance at 0x0000018AA9EC95E0>
#
#
#
# wrap <function wrap at 0x0000018AA5EC88B0>
#
#
#
# BCD_To_Decimal <function BCD_To_Decimal at 0x0000018AA9EC9DC0>
#
#
#
# BCD_To_Ex3 <function BCD_To_Ex3 at 0x0000018AA9EC9EE0>
#
#
#
# Binary_Adder <function Binary_Adder at 0x0000018AA9EC9820>
#
#
#
# Binary_Division <function Binary_Division at 0x0000018AA9EC99D0>
#
#
#
# Binary_Subtractor <function Binary_Subtractor at 0x0000018AA9EC98B0>
#
#
#
# Binary_Subtractor_2 <function Binary_Subtractor_2 at 0x0000018AA9EC9940>
#
#
#
# Binary_To_Gray <function Binary_To_Gray at 0x0000018AA9EC9C10>
#
#
#
# COMPLIMENTS <function COMPLIMENTS at 0x0000018AA93831F0>
#
#
#
# ChrToVal <function ChrToVal at 0x0000018AA9EC9A60>
#
#
#
# Decimal_To_BCD <function Decimal_To_BCD at 0x0000018AA9EC9E50>
#
#
#
# Decimal_To_X <function Decimal_To_X at 0x0000018AA9EC9D30>
#
#
#
# Format <function Format at 0x0000018AA9EC9790>
#
#
#
# NS_Code_Converter <function NS_Code_Converter at 0x0000018AA9EC9F70>
#
#
#
# Print_List <function Print_List at 0x0000018AA9EC9B80>
#
#
#
# Propositional_Truth_Table <function Propositional_Truth_Table at 0x0000018AA9383280>
#
#
#
# Split <function Split at 0x0000018AA9383040>
#
#
#
# ValToChr <function ValToChr at 0x0000018AA9EC9AF0>
#
#
#
# X_To_Decimal <function X_To_Decimal at 0x0000018AA9EC9CA0>
#
#
#
# _1sCOMPLIMENT <function _1sCOMPLIMENT at 0x0000018AA93830D0>
#
#
#
# _2sCOMPLIMENT <function _2sCOMPLIMENT at 0x0000018AA9383160>
#
#
#
# Chinese_Remainder_Theorem <function Chinese_Remainder_Theorem at 0x0000018AAA00D310>
#
#
#
# Co_Prime <function Co_Prime at 0x0000018AAA00D0D0>
#
#
#
# Congruent_Modulo <function Congruent_Modulo at 0x0000018AAA001C10>
#
#
#
# Determinant <function Determinant at 0x0000018AAA00D670>
#
#
#
# Euler_Totient_Function <function Euler_Totient_Function at 0x0000018AAA00D430>
#
#
#
# Fibonacci <function Fibonacci at 0x0000018AAA00D9D0>
#
#
#
# Inverse_Euler_Totient_Function <function Inverse_Euler_Totient_Function at 0x0000018AAA00D550>
#
#
#
# Josephus_Problem <function Josephus_Problem at 0x0000018AAA00D8B0>
#
#
#
# Last_Digit_Determiner <function Last_Digit_Determiner at 0x0000018AAA00D790>
#
#
#
# ModAll <function ModAll at 0x0000018AAA00DAF0>
#
#
#
# Prime_Check <function Prime_Check at 0x0000018AAA001F70>
#
#
#
# Prime_Factors <function Prime_Factors at 0x0000018AAA001E50>
#
#
#
# Sieve <function Sieve at 0x0000018AAA001D30>
#
#
#
# Signum <function Signum at 0x0000018AAA00D1F0>
#
#
#
# addNums <function addNums at 0x0000018AAA00DB80>
#
#
#
# BiasedEvents <function BiasedEvents at 0x0000018AAA036280>
#
#
#
# Random_Dates <function Random_Dates at 0x0000018AAA036430>
#
#
#
# Random_Element <function Random_Element at 0x0000018AAA00DCA0>
#
#
#
# Random_Range <function Random_Range at 0x0000018AAA0361F0>
#
#
#
# Shuffle_Zip <function Shuffle_Zip at 0x0000018AAA0363A0>
#
#
#
# Shuffler <function Shuffler at 0x0000018AAA036310>
#
#
#
# APs_smallest_common_ele <function APs_smallest_common_ele at 0x0000018AAA0364C0>
#
#
#
# Combinations <function Combinations at 0x0000018AAA0369D0>
#
#
#
# Permutations <function Permutations at 0x0000018AAA036820>

# %%
functions
# Out:
# {'CRC_Decoder': <function bcn.py.CRC_Decoder(Data: str, Divisor: str) -> str>,
#  'CRC_Encoder': <function bcn.py.CRC_Encoder(Data: str, Divisor: str) -> str>,
#  'MHD_ED_EC': <function bcn.py.MHD_ED_EC(word_1: list, word_2: list = None) -> dict>,
#  'TimeIt': <function bcn.py.TimeIt(stmts, setups, numbers)>,
#  '_1sComp_CheckSum_Checker': <function bcn.py._1sComp_CheckSum_Checker(Data_List: list) -> list>,
#  '_1sComp_CheckSum_Generator': <function bcn.py._1sComp_CheckSum_Generator(Data_List: list) -> list>,
#  'hamming_distance': <function bcn.py.hamming_distance(word_1: list, word_2: list = None) -> int>,
#  'wrap': <function textwrap.wrap(text, width=70, **kwargs)>,
#  'BCD_To_Decimal': <function ldco.py.BCD_To_Decimal(nfc: str, EachDigitLen: int = 4) -> str>,
#  'BCD_To_Ex3': <function ldco.py.BCD_To_Ex3(nfc: str, EachDigitLen: int = 4) -> str>,
#  'Binary_Adder': <function ldco.py.Binary_Adder(Numbers_List: list, Base_System: int = 10) -> str>,
#  'Binary_Division': <function ldco.py.Binary_Division(Dividend: str, Divisor: str) -> tuple>,
#  'Binary_Subtractor': <function ldco.py.Binary_Subtractor(Minuend: str, Subtrahend: str, Borrow: int = 0) -> str>,
#  'Binary_Subtractor_2': <function ldco.py.Binary_Subtractor_2(Minuend: str, Subtrahend: str) -> str>,
#  'Binary_To_Gray': <function ldco.py.Binary_To_Gray(Number: str, BTG: bool = True) -> str>,
#  'COMPLIMENTS': <function ldco.py.COMPLIMENTS() -> None>,
#  'ChrToVal': <function ldco.py.ChrToVal(N)>,
#  'Decimal_To_BCD': <function ldco.py.Decimal_To_BCD(nfc: str, EachDigitLen: int = 4) -> str>,
#  'Decimal_To_X': <function ldco.py.Decimal_To_X(nDec: int, to: int, conv: str = '') -> str>,
#  'Format': <function ldco.py.Format(Numbers_List: list) -> str>,
#  'NS_Code_Converter': <function ldco.py.NS_Code_Converter(nfc: str = None, From: str = None, To: str = None) -> str>,
#  'Print_List': <function ldco.py.Print_List(Message='Choice')>,
#  'Propositional_Truth_Table': <function ldco.py.Propositional_Truth_Table(Exp: str = '((pvqvy)^~q)>r=t=s') -> None>,
#  'Split': <function ldco.py.Split(String: str, Splitters, KeepSplitters=False, StripElements=False)>,
#  'ValToChr': <function ldco.py.ValToChr(N)>,
#  'X_To_Decimal': <function ldco.py.X_To_Decimal(nfc: str, From: int, nDec: int = 0) -> int>,
#  '_1sCOMPLIMENT': <function ldco.py._1sCOMPLIMENT(Number: str) -> str>,
#  '_2sCOMPLIMENT': <function ldco.py._2sCOMPLIMENT(Number: str) -> str>,
#  'Chinese_Remainder_Theorem': <function fusion.py.Chinese_Remainder_Theorem(Divisor_Array: list, Remainder_Array: list) -> int>,
#  'Co_Prime': <function fusion.py.Co_Prime(Number_1: int, Number_2: int) -> bool>,
#  'Congruent_Modulo': <function fusion.py.Congruent_Modulo(List: list, N: int) -> dict>,
#  'Determinant': <function fusion.py.Determinant(Mat: list) -> int>,
#  'Euler_Totient_Function': <function fusion.py.Euler_Totient_Function(Number: int) -> int>,
#  'Fibonacci': <function fusion.py.Fibonacci(n: int) -> int>,
#  'Inverse_Euler_Totient_Function': <function fusion.py.Inverse_Euler_Totient_Function(Number: int) -> int>,
#  'Josephus_Problem': <function fusion.py.Josephus_Problem(Step: int, Sequence: list) -> int>,
#  'Last_Digit_Determiner': <function fusion.py.Last_Digit_Determiner(Base: int, Exponent: int) -> int>,
#  'ModAll': <function fusion.py.ModAll(List: list, Number: int) -> list>,
#  'Prime_Check': <function fusion.py.Prime_Check(Number: int) -> int>,
#  'Prime_Factors': <function fusion.py.Prime_Factors(Number: int) -> list>,
#  'Sieve': <function fusion.py.Sieve(Number: int) -> list>,
#  'Signum': <function fusion.py.Signum(Number: int) -> int>,
#  'addNums': <function more.py.addNums(lst1: list, lst2: list, *args)>,
#  'BiasedEvents': <function Randomizer.py.BiasedEvents(Sequence: list, NoOfDraws: int) -> int>,
#  'Random_Dates': <function Randomizer.py.Random_Dates(Freq: int = 10, dayR: tuple = (1, 31), monthR: tuple = (1, 12), yearR: tuple = (2000, 2021), Format: str = 'YYYY-MM-DD')>,
#  'Random_Element': <function Randomizer.py.Random_Element(Sequence: list, start: int = 0, end: int = -1) -> list>,
#  'Random_Range': <function Randomizer.py.Random_Range(start: int, end: int) -> int>,
#  'Shuffle_Zip': <function Randomizer.py.Shuffle_Zip(length: int = -1, Sequence1: list = ['Coco', 'Nova'], Sequence2: list = ['Nina', 'Hande', 'Candice'], *args)>,
#  'Shuffler': <function Randomizer.py.Shuffler(Sequence: Union[list, tuple, set]) -> Union[list, tuple, set, int]>,
#  'APs_smallest_common_ele': <function seq_n_series.py.APs_smallest_common_ele(a: int, b: int, c: int, d: int) -> int>,
#  'Combinations': <function Permutations_and_Combinations.py.Combinations(Elements: list, Positions: int = -1)>,
#  'Permutations': <function Permutations_and_Combinations.py.Permutations(Elements: list, Positions: int = -1, Allow_Repetitions: bool = False)>}

# %%
func_Lib = functions.values()
func_Lib
# Out:
# dict_values([<function CRC_Decoder at 0x0000018AA9EC9430>, <function CRC_Encoder at 0x0000018AA9201B80>, <function MHD_ED_EC at 0x0000018AA9EC9670>, <function TimeIt at 0x0000018AA98B2160>, <function _1sComp_CheckSum_Checker at 0x0000018AA9EC9550>, <function _1sComp_CheckSum_Generator at 0x0000018AA9EC94C0>, <function hamming_distance at 0x0000018AA9EC95E0>, <function wrap at 0x0000018AA5EC88B0>, <function BCD_To_Decimal at 0x0000018AA9EC9DC0>, <function BCD_To_Ex3 at 0x0000018AA9EC9EE0>, <function Binary_Adder at 0x0000018AA9EC9820>, <function Binary_Division at 0x0000018AA9EC99D0>, <function Binary_Subtractor at 0x0000018AA9EC98B0>, <function Binary_Subtractor_2 at 0x0000018AA9EC9940>, <function Binary_To_Gray at 0x0000018AA9EC9C10>, <function COMPLIMENTS at 0x0000018AA93831F0>, <function ChrToVal at 0x0000018AA9EC9A60>, <function Decimal_To_BCD at 0x0000018AA9EC9E50>, <function Decimal_To_X at 0x0000018AA9EC9D30>, <function Format at 0x0000018AA9EC9790>, <function NS_Code_Converter at 0x0000018AA9EC9F70>, <function Print_List at 0x0000018AA9EC9B80>, <function Propositional_Truth_Table at 0x0000018AA9383280>, <function Split at 0x0000018AA9383040>, <function ValToChr at 0x0000018AA9EC9AF0>, <function X_To_Decimal at 0x0000018AA9EC9CA0>, <function _1sCOMPLIMENT at 0x0000018AA93830D0>, <function _2sCOMPLIMENT at 0x0000018AA9383160>, <function Chinese_Remainder_Theorem at 0x0000018AAA00D310>, <function Co_Prime at 0x0000018AAA00D0D0>, <function Congruent_Modulo at 0x0000018AAA001C10>, <function Determinant at 0x0000018AAA00D670>, <function Euler_Totient_Function at 0x0000018AAA00D430>, <function Fibonacci at 0x0000018AAA00D9D0>, <function Inverse_Euler_Totient_Function at 0x0000018AAA00D550>, <function Josephus_Problem at 0x0000018AAA00D8B0>, <function Last_Digit_Determiner at 0x0000018AAA00D790>, <function ModAll at 0x0000018AAA00DAF0>, <function Prime_Check at 0x0000018AAA001F70>, <function Prime_Factors at 0x0000018AAA001E50>, <function Sieve at 0x0000018AAA001D30>, <function Signum at 0x0000018AAA00D1F0>, <function addNums at 0x0000018AAA00DB80>, <function BiasedEvents at 0x0000018AAA036280>, <function Random_Dates at 0x0000018AAA036430>, <function Random_Element at 0x0000018AAA00DCA0>, <function Random_Range at 0x0000018AAA0361F0>, <function Shuffle_Zip at 0x0000018AAA0363A0>, <function Shuffler at 0x0000018AAA036310>, <function APs_smallest_common_ele at 0x0000018AAA0364C0>, <function Combinations at 0x0000018AAA0369D0>, <function Permutations at 0x0000018AAA036820>])

# %%
from inspect import signature




Dict = {
    'function_name': {
          'docS': 'tooltip',
          'params': {
              'p1': ['int', 'tooltip'],
              'p2': ['str', 'tooltip']
          },
    
          'returns': {
              'r1': ['list', 'tooltip']
          },
    
          'tags': ['tag1', 'tag2']
    }
}


Dict = {}


pyDT_To_HTML = {
    float: 'number',
    int: 'number',
    str: 'text',
    range: 'range',
    list: 'range',
    tuple: 'range',
    set: 'range',
}

for func in func_Lib:
    Sig = signature(func)
    Dict[func.__name__] = {}
    Dict[func.__name__]['docS'] = func.__doc__
    Dict[func.__name__]['params'] = { name : Type.annotation for name, Type in Sig.parameters.items() }
    Dict[func.__name__]['returns'] = { 'r1' : Sig.return_annotation }
    Dict[func.__name__]['call'] = func

Dict
# Out:
# {'CRC_Decoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': <function bcn.py.CRC_Decoder(Data: str, Divisor: str) -> str>},
#  'CRC_Encoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': <function bcn.py.CRC_Encoder(Data: str, Divisor: str) -> str>},
#  'MHD_ED_EC': {'docS': 'Minimum hamming distance(MHD), Error detection(ED), Error correction(EC)\n        ==========================================================\n        Calculates\n        ----------\n        1. Minimum Hamming Distance (d_min) between given 2 code-words\n        2. Number of errors that can be detected\n        3. Number of errors that can be corrected\n    ',
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': dict[str, int]},
#   'call': <function bcn.py.MHD_ED_EC(word_1: list, word_2: list = None) -> dict>},
#  'TimeIt': {'docS': None,
#   'params': {'stmts': inspect._empty,
#    'setups': inspect._empty,
#    'numbers': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function bcn.py.TimeIt(stmts, setups, numbers)>},
#  '_1sComp_CheckSum_Checker': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': <function bcn.py._1sComp_CheckSum_Checker(Data_List: list) -> list>},
#  '_1sComp_CheckSum_Generator': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': <function bcn.py._1sComp_CheckSum_Generator(Data_List: list) -> list>},
#  'hamming_distance': {'docS': None,
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': int},
#   'call': <function bcn.py.hamming_distance(word_1: list, word_2: list = None) -> int>},
#  'wrap': {'docS': "Wrap a single paragraph of text, returning a list of wrapped lines.\n\n    Reformat the single paragraph in 'text' so it fits in lines of no\n    more than 'width' columns, and return a list of wrapped lines.  By\n    default, tabs in 'text' are expanded with string.expandtabs(), and\n    all other whitespace characters (including newline) are converted to\n    space.  See TextWrapper class for available keyword args to customize\n    wrapping behaviour.\n    ",
#   'params': {'text': inspect._empty,
#    'width': inspect._empty,
#    'kwargs': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function textwrap.wrap(text, width=70, **kwargs)>},
#  'BCD_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.BCD_To_Decimal(nfc: str, EachDigitLen: int = 4) -> str>},
#  'BCD_To_Ex3': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.BCD_To_Ex3(nfc: str, EachDigitLen: int = 4) -> str>},
#  'Binary_Adder': {'docS': 'PERFORMS ADDITION ON A LIST OF NUMBERS IN BASE SYSTEM Base_System',
#   'params': {'Numbers_List': list, 'Base_System': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Adder(Numbers_List: list, Base_System: int = 10) -> str>},
#  'Binary_Division': {'docS': None,
#   'params': {'Dividend': str, 'Divisor': str},
#   'returns': {'r1': tuple},
#   'call': <function ldco.py.Binary_Division(Dividend: str, Divisor: str) -> tuple>},
#  'Binary_Subtractor': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str, 'Borrow': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Subtractor(Minuend: str, Subtrahend: str, Borrow: int = 0) -> str>},
#  'Binary_Subtractor_2': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_Subtractor_2(Minuend: str, Subtrahend: str) -> str>},
#  'Binary_To_Gray': {'docS': None,
#   'params': {'Number': str, 'BTG': bool},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Binary_To_Gray(Number: str, BTG: bool = True) -> str>},
#  'COMPLIMENTS': {'docS': None,
#   'params': {},
#   'returns': {'r1': None},
#   'call': <function ldco.py.COMPLIMENTS() -> None>},
#  'ChrToVal': {'docS': None,
#   'params': {'N': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function ldco.py.ChrToVal(N)>},
#  'Decimal_To_BCD': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Decimal_To_BCD(nfc: str, EachDigitLen: int = 4) -> str>},
#  'Decimal_To_X': {'docS': None,
#   'params': {'nDec': int, 'to': int, 'conv': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Decimal_To_X(nDec: int, to: int, conv: str = '') -> str>},
#  'Format': {'docS': 'Returns All Numbers with Uniform Length',
#   'params': {'Numbers_List': list},
#   'returns': {'r1': str},
#   'call': <function ldco.py.Format(Numbers_List: list) -> str>},
#  'NS_Code_Converter': {'docS': None,
#   'params': {'nfc': str, 'From': str, 'To': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py.NS_Code_Converter(nfc: str = None, From: str = None, To: str = None) -> str>},
#  'Print_List': {'docS': None,
#   'params': {'Message': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function ldco.py.Print_List(Message='Choice')>},
#  'Propositional_Truth_Table': {'docS': None,
#   'params': {'Exp': str},
#   'returns': {'r1': None},
#   'call': <function ldco.py.Propositional_Truth_Table(Exp: str = '((pvqvy)^~q)>r=t=s') -> None>},
#  'Split': {'docS': None,
#   'params': {'String': str,
#    'Splitters': inspect._empty,
#    'KeepSplitters': inspect._empty,
#    'StripElements': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function ldco.py.Split(String: str, Splitters, KeepSplitters=False, StripElements=False)>},
#  'ValToChr': {'docS': None,
#   'params': {'N': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function ldco.py.ValToChr(N)>},
#  'X_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'From': int, 'nDec': int},
#   'returns': {'r1': int},
#   'call': <function ldco.py.X_To_Decimal(nfc: str, From: int, nDec: int = 0) -> int>},
#  '_1sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py._1sCOMPLIMENT(Number: str) -> str>},
#  '_2sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': <function ldco.py._2sCOMPLIMENT(Number: str) -> str>},
#  'Chinese_Remainder_Theorem': {'docS': 'CHINESE REMAINDER THEOREM :- Implements CRT on Given Divisor and Remainder Arrays',
#   'params': {'Divisor_Array': list, 'Remainder_Array': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Chinese_Remainder_Theorem(Divisor_Array: list, Remainder_Array: list) -> int>},
#  'Co_Prime': {'docS': 'CO-PRIME :- Checks Whether Given Pair of Numbers are Co-Prime',
#   'params': {'Number_1': int, 'Number_2': int},
#   'returns': {'r1': bool},
#   'call': <function fusion.py.Co_Prime(Number_1: int, Number_2: int) -> bool>},
#  'Congruent_Modulo': {'docS': "CONGRUENT_MODULO :- Groups 'List' elements giving identical modulus value w.r.t. 'Number'",
#   'params': {'List': list, 'N': int},
#   'returns': {'r1': dict},
#   'call': <function fusion.py.Congruent_Modulo(List: list, N: int) -> dict>},
#  'Determinant': {'docS': 'JUST ONE LINE DETERMINANT CALCULATOR :- Calculates Determinant of given Matrix',
#   'params': {'Mat': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Determinant(Mat: list) -> int>},
#  'Euler_Totient_Function': {'docS': 'EULER TOTIENT FUNCTION :- Computes ETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Euler_Totient_Function(Number: int) -> int>},
#  'Fibonacci': {'docS': 'FIBONACCI :- Provides fibonacci result upto 998\n    n -> depicts element position in the fibonacci sequence\n    ',
#   'params': {'n': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Fibonacci(n: int) -> int>},
#  'Inverse_Euler_Totient_Function': {'docS': 'INVERSE EULER TOTIENT FUNCTION :- Computes IETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Inverse_Euler_Totient_Function(Number: int) -> int>},
#  'Josephus_Problem': {'docS': 'JOSEPHUS PROBLEM :- Theoretical problem related to a certain counting-out game',
#   'params': {'Step': int, 'Sequence': list},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Josephus_Problem(Step: int, Sequence: list) -> int>},
#  'Last_Digit_Determiner': {'docS': 'PRINTS LAST DIGIT OF EXPONENTIAL RESULT :- Determines Last Digit of Result (Base ^ Exp)',
#   'params': {'Base': int, 'Exponent': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Last_Digit_Determiner(Base: int, Exponent: int) -> int>},
#  'ModAll': {'docS': "MODALL :- Performs modulus(%) operation on given elements in 'List' w.r.t. 'Number'",
#   'params': {'List': list, 'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.ModAll(List: list, Number: int) -> list>},
#  'Prime_Check': {'docS': 'PRIME CHECK :- Checks if a Number is Prime / Composite / Neither Prime nor Composite',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Prime_Check(Number: int) -> int>},
#  'Prime_Factors': {'docS': 'PRIME FACTORS :- Computes List of Prime Factors',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.Prime_Factors(Number: int) -> list>},
#  'Sieve': {'docS': 'SIEVE OF ERASTOSTHENES :- Computes Sieve of Eratosthenes',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': <function fusion.py.Sieve(Number: int) -> list>},
#  'Signum': {'docS': 'SIGNUM :- Checks Sign of Number in Range = { -1, 0, 1 }',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': <function fusion.py.Signum(Number: int) -> int>},
#  'addNums': {'docS': '\n    Numbers Adder\n    =============\n    Given a list of list of digits of numbers, the function returns the list of digits of the resulting sum.\n    The lists(numbers) can be of different sizes\n    \n    Parameters\n    ----------\n    1. lst1 : list - digits of first number\n    2. lst2 : list - digits of second number\n    3. *args : (Optional) list of lists - more numbers\n\n    Returns\n    -------\n    the list of digits of the resulting Sum (carry considered)\n\n    Example\n    -------\n    >>> num1 = [7, 6, 9, 8, 8]              # Depicts number 76988\n    >>> num2 = [5, 9, 2]                    # Depicts number 592\n    >>> num3 = [3, 5, 1, 7, 4]              # Depicts number 35174\n    >>> print(addNums(num1, num2, num3))    # Output: [1, 1, 2, 7, 5, 4] (112754)\n    ',
#   'params': {'lst1': list[int], 'lst2': list[int], 'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function more.py.addNums(lst1: list, lst2: list, *args)>},
#  'BiasedEvents': {'docS': 'Biased Events\n        ============\n        Method Takes Input of Biased Probability of unique elements and number of outcomes/draws\n    ',
#   'params': {'Sequence': list, 'NoOfDraws': int},
#   'returns': {'r1': int},
#   'call': <function Randomizer.py.BiasedEvents(Sequence: list, NoOfDraws: int) -> int>},
#  'Random_Dates': {'docS': 'Random Dates Generator\n        =====================\n        Generates random dates according to input parameters\n\n        Parameters\n        ----------\n        dayR : int -> day range\n        monthR : int -> month range\n        yearR : int -> year range\n        Format : int -> date format\n    ',
#   'params': {'Freq': int,
#    'dayR': tuple,
#    'monthR': tuple,
#    'yearR': tuple,
#    'Format': str},
#   'returns': {'r1': inspect._empty},
#   'call': <function Randomizer.py.Random_Dates(Freq: int = 10, dayR: tuple = (1, 31), monthR: tuple = (1, 12), yearR: tuple = (2000, 2021), Format: str = 'YYYY-MM-DD')>},
#  'Random_Element': {'docS': None,
#   'params': {'Sequence': list[int], 'start': int, 'end': int},
#   'returns': {'r1': list[int]},
#   'call': <function Randomizer.py.Random_Element(Sequence: list, start: int = 0, end: int = -1) -> list>},
#  'Random_Range': {'docS': 'Random Range\n        ===========\n        Returns random number in specified range\n    ',
#   'params': {'start': int, 'end': int},
#   'returns': {'r1': int},
#   'call': <function Randomizer.py.Random_Range(start: int, end: int) -> int>},
#  'Shuffle_Zip': {'docS': 'Shuffle Zip\n        ==========\n        Shuffle Individual Sequences and Group(zip)\n    ',
#   'params': {'length': int,
#    'Sequence1': list[str],
#    'Sequence2': list[str],
#    'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': <function Randomizer.py.Shuffle_Zip(length: int = -1, Sequence1: list = ['Coco', 'Nova'], Sequence2: list = ['Nina', 'Hande', 'Candice'], *args)>},
#  'Shuffler': {'docS': 'Shuffler\n        =======\n        For Picking Random element from a sequence\n    ',
#   'params': {'Sequence': typing.Union[list, tuple, set]},
#   'returns': {'r1': typing.Union[list, tuple, set, int]},
#   'call': <function Randomizer.py.Shuffler(Sequence: Union[list, tuple, set]) -> Union[list, tuple, set, int]>},
#  'APs_smallest_common_ele': {'docS': '\n        Smallest Common Element\n        =======================\n        Finds smallest common element of the Arithmetic Progressions (APs) whose initial terms and common differences are given\n        AP 1: a + (n-1)*b\n        AP 2: b + (m-1)*d\n        \n        Parameters\n        ----------\n        a : int -> initial term of first AP\n        b : int -> common difference of first AP\n        c : int -> initial term of second AP\n        d : int -> common difference of second AP\n\n        Returns\n        -------\n        int : first common term (first intersection) of 2 APs which satisfies (a+(n-1)*b = c+(m-1)*d) if exists, else -1\n    ',
#   'params': {'a': int, 'b': int, 'c': int, 'd': int},
#   'returns': {'r1': int},
#   'call': <function seq_n_series.py.APs_smallest_common_ele(a: int, b: int, c: int, d: int) -> int>},
#  'Combinations': {'docS': 'COMBINATIONS :- Returns List of All Possible Combinations of Input Data',
#   'params': {'Elements': list, 'Positions': int},
#   'returns': {'r1': inspect._empty},
#   'call': <function Permutations_and_Combinations.py.Combinations(Elements: list, Positions: int = -1)>},
#  'Permutations': {'docS': 'PERMUTATIONS :- Returns List of All Possible Permutations of Input Data',
#   'params': {'Elements': list, 'Positions': int, 'Allow_Repetitions': bool},
#   'returns': {'r1': inspect._empty},
#   'call': <function Permutations_and_Combinations.py.Permutations(Elements: list, Positions: int = -1, Allow_Repetitions: bool = False)>}}

# %%
import pickle
path = "manager"
pickle.dump(Dict, open("funcDict.pkl", 'wb'))
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5168/447163348.py in <module>
#       1 import pickle
#       2 path = "manager"
# ----> 3 pickle.dump(Dict, open("funcDict.pkl", 'wb'))
#
# PicklingError: Can't pickle <function CRC_Decoder at 0x0000018AA9EC9430>: import of module 'bcn.py' failed

# %%
dict = pickle.load(open("funcDict.pkl", 'rb'))
dict
# Out:
# {'CRC_Decoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': 1},
#  'CRC_Encoder': {'docS': None,
#   'params': {'Data': str, 'Divisor': str},
#   'returns': {'r1': str},
#   'call': 1},
#  'MHD_ED_EC': {'docS': 'Minimum hamming distance(MHD), Error detection(ED), Error correction(EC)\n        ==========================================================\n        Calculates\n        ----------\n        1. Minimum Hamming Distance (d_min) between given 2 code-words\n        2. Number of errors that can be detected\n        3. Number of errors that can be corrected\n    ',
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': dict[str, int]},
#   'call': 1},
#  'TimeIt': {'docS': None,
#   'params': {'stmts': inspect._empty,
#    'setups': inspect._empty,
#    'numbers': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  '_1sComp_CheckSum_Checker': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': 1},
#  '_1sComp_CheckSum_Generator': {'docS': None,
#   'params': {'Data_List': list[str]},
#   'returns': {'r1': list[str]},
#   'call': 1},
#  'hamming_distance': {'docS': None,
#   'params': {'word_1': list[str], 'word_2': list[str]},
#   'returns': {'r1': int},
#   'call': 1},
#  'wrap': {'docS': "Wrap a single paragraph of text, returning a list of wrapped lines.\n\n    Reformat the single paragraph in 'text' so it fits in lines of no\n    more than 'width' columns, and return a list of wrapped lines.  By\n    default, tabs in 'text' are expanded with string.expandtabs(), and\n    all other whitespace characters (including newline) are converted to\n    space.  See TextWrapper class for available keyword args to customize\n    wrapping behaviour.\n    ",
#   'params': {'text': inspect._empty,
#    'width': inspect._empty,
#    'kwargs': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'BCD_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': 1},
#  'BCD_To_Ex3': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': 1},
#  'Binary_Adder': {'docS': 'PERFORMS ADDITION ON A LIST OF NUMBERS IN BASE SYSTEM Base_System',
#   'params': {'Numbers_List': list, 'Base_System': int},
#   'returns': {'r1': str},
#   'call': 1},
#  'Binary_Division': {'docS': None,
#   'params': {'Dividend': str, 'Divisor': str},
#   'returns': {'r1': tuple},
#   'call': 1},
#  'Binary_Subtractor': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str, 'Borrow': int},
#   'returns': {'r1': str},
#   'call': 1},
#  'Binary_Subtractor_2': {'docS': None,
#   'params': {'Minuend': str, 'Subtrahend': str},
#   'returns': {'r1': str},
#   'call': 1},
#  'Binary_To_Gray': {'docS': None,
#   'params': {'Number': str, 'BTG': bool},
#   'returns': {'r1': str},
#   'call': 1},
#  'COMPLIMENTS': {'docS': None,
#   'params': {},
#   'returns': {'r1': None},
#   'call': 1},
#  'ChrToVal': {'docS': None,
#   'params': {'N': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'Decimal_To_BCD': {'docS': None,
#   'params': {'nfc': str, 'EachDigitLen': int},
#   'returns': {'r1': str},
#   'call': 1},
#  'Decimal_To_X': {'docS': None,
#   'params': {'nDec': int, 'to': int, 'conv': str},
#   'returns': {'r1': str},
#   'call': 1},
#  'Format': {'docS': 'Returns All Numbers with Uniform Length',
#   'params': {'Numbers_List': list},
#   'returns': {'r1': str},
#   'call': 1},
#  'NS_Code_Converter': {'docS': None,
#   'params': {'nfc': str, 'From': str, 'To': str},
#   'returns': {'r1': str},
#   'call': 1},
#  'Print_List': {'docS': None,
#   'params': {'Message': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'Propositional_Truth_Table': {'docS': None,
#   'params': {'Exp': str},
#   'returns': {'r1': None},
#   'call': 1},
#  'Split': {'docS': None,
#   'params': {'String': str,
#    'Splitters': inspect._empty,
#    'KeepSplitters': inspect._empty,
#    'StripElements': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'ValToChr': {'docS': None,
#   'params': {'N': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'X_To_Decimal': {'docS': None,
#   'params': {'nfc': str, 'From': int, 'nDec': int},
#   'returns': {'r1': int},
#   'call': 1},
#  '_1sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': 1},
#  '_2sCOMPLIMENT': {'docS': None,
#   'params': {'Number': str},
#   'returns': {'r1': str},
#   'call': 1},
#  'Chinese_Remainder_Theorem': {'docS': 'CHINESE REMAINDER THEOREM :- Implements CRT on Given Divisor and Remainder Arrays',
#   'params': {'Divisor_Array': list, 'Remainder_Array': list},
#   'returns': {'r1': int},
#   'call': 1},
#  'Co_Prime': {'docS': 'CO-PRIME :- Checks Whether Given Pair of Numbers are Co-Prime',
#   'params': {'Number_1': int, 'Number_2': int},
#   'returns': {'r1': bool},
#   'call': 1},
#  'Congruent_Modulo': {'docS': "CONGRUENT_MODULO :- Groups 'List' elements giving identical modulus value w.r.t. 'Number'",
#   'params': {'List': list, 'N': int},
#   'returns': {'r1': dict},
#   'call': 1},
#  'Determinant': {'docS': 'JUST ONE LINE DETERMINANT CALCULATOR :- Calculates Determinant of given Matrix',
#   'params': {'Mat': list},
#   'returns': {'r1': int},
#   'call': 1},
#  'Euler_Totient_Function': {'docS': 'EULER TOTIENT FUNCTION :- Computes ETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'Fibonacci': {'docS': 'FIBONACCI :- Provides fibonacci result upto 998\n    n -> depicts element position in the fibonacci sequence\n    ',
#   'params': {'n': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'Inverse_Euler_Totient_Function': {'docS': 'INVERSE EULER TOTIENT FUNCTION :- Computes IETF for given Number',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'Josephus_Problem': {'docS': 'JOSEPHUS PROBLEM :- Theoretical problem related to a certain counting-out game',
#   'params': {'Step': int, 'Sequence': list},
#   'returns': {'r1': int},
#   'call': 1},
#  'Last_Digit_Determiner': {'docS': 'PRINTS LAST DIGIT OF EXPONENTIAL RESULT :- Determines Last Digit of Result (Base ^ Exp)',
#   'params': {'Base': int, 'Exponent': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'ModAll': {'docS': "MODALL :- Performs modulus(%) operation on given elements in 'List' w.r.t. 'Number'",
#   'params': {'List': list, 'Number': int},
#   'returns': {'r1': list},
#   'call': 1},
#  'Prime_Check': {'docS': 'PRIME CHECK :- Checks if a Number is Prime / Composite / Neither Prime nor Composite',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'Prime_Factors': {'docS': 'PRIME FACTORS :- Computes List of Prime Factors',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': 1},
#  'Sieve': {'docS': 'SIEVE OF ERASTOSTHENES :- Computes Sieve of Eratosthenes',
#   'params': {'Number': int},
#   'returns': {'r1': list},
#   'call': 1},
#  'Signum': {'docS': 'SIGNUM :- Checks Sign of Number in Range = { -1, 0, 1 }',
#   'params': {'Number': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'addNums': {'docS': '\n    Numbers Adder\n    =============\n    Given a list of list of digits of numbers, the function returns the list of digits of the resulting sum.\n    The lists(numbers) can be of different sizes\n    \n    Parameters\n    ----------\n    1. lst1 : list - digits of first number\n    2. lst2 : list - digits of second number\n    3. *args : (Optional) list of lists - more numbers\n\n    Returns\n    -------\n    the list of digits of the resulting Sum (carry considered)\n\n    Example\n    -------\n    >>> num1 = [7, 6, 9, 8, 8]              # Depicts number 76988\n    >>> num2 = [5, 9, 2]                    # Depicts number 592\n    >>> num3 = [3, 5, 1, 7, 4]              # Depicts number 35174\n    >>> print(addNums(num1, num2, num3))    # Output: [1, 1, 2, 7, 5, 4] (112754)\n    ',
#   'params': {'lst1': list[int], 'lst2': list[int], 'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'BiasedEvents': {'docS': 'Biased Events\n        ============\n        Method Takes Input of Biased Probability of unique elements and number of outcomes/draws\n    ',
#   'params': {'Sequence': list, 'NoOfDraws': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'Random_Dates': {'docS': 'Random Dates Generator\n        =====================\n        Generates random dates according to input parameters\n\n        Parameters\n        ----------\n        dayR : int -> day range\n        monthR : int -> month range\n        yearR : int -> year range\n        Format : int -> date format\n    ',
#   'params': {'Freq': int,
#    'dayR': tuple,
#    'monthR': tuple,
#    'yearR': tuple,
#    'Format': str},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'Random_Element': {'docS': None,
#   'params': {'Sequence': list[int], 'start': int, 'end': int},
#   'returns': {'r1': list[int]},
#   'call': 1},
#  'Random_Range': {'docS': 'Random Range\n        ===========\n        Returns random number in specified range\n    ',
#   'params': {'start': int, 'end': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'Shuffle_Zip': {'docS': 'Shuffle Zip\n        ==========\n        Shuffle Individual Sequences and Group(zip)\n    ',
#   'params': {'length': int,
#    'Sequence1': list[str],
#    'Sequence2': list[str],
#    'args': inspect._empty},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'Shuffler': {'docS': 'Shuffler\n        =======\n        For Picking Random element from a sequence\n    ',
#   'params': {'Sequence': typing.Union[list, tuple, set]},
#   'returns': {'r1': typing.Union[list, tuple, set, int]},
#   'call': 1},
#  'APs_smallest_common_ele': {'docS': '\n        Smallest Common Element\n        =======================\n        Finds smallest common element of the Arithmetic Progressions (APs) whose initial terms and common differences are given\n        AP 1: a + (n-1)*b\n        AP 2: b + (m-1)*d\n        \n        Parameters\n        ----------\n        a : int -> initial term of first AP\n        b : int -> common difference of first AP\n        c : int -> initial term of second AP\n        d : int -> common difference of second AP\n\n        Returns\n        -------\n        int : first common term (first intersection) of 2 APs which satisfies (a+(n-1)*b = c+(m-1)*d) if exists, else -1\n    ',
#   'params': {'a': int, 'b': int, 'c': int, 'd': int},
#   'returns': {'r1': int},
#   'call': 1},
#  'Combinations': {'docS': 'COMBINATIONS :- Returns List of All Possible Combinations of Input Data',
#   'params': {'Elements': list, 'Positions': int},
#   'returns': {'r1': inspect._empty},
#   'call': 1},
#  'Permutations': {'docS': 'PERMUTATIONS :- Returns List of All Possible Permutations of Input Data',
#   'params': {'Elements': list, 'Positions': int, 'Allow_Repetitions': bool},
#   'returns': {'r1': inspect._empty},
#   'call': 1}}
